# %%
import eutils

# %%
ec = eutils.client.Client()
search_result = ec.esearch('pubmed', term='HOTAIR')
paset = list(ec.efetch('pubmed', search_result.ids))

for i, pa in enumerate(paset):
    print('%3d - %s' % (i, pa.title))
# Out:
# WARNING:eutils.client:NCBI found 528 results, but we truncated the reply at 250 results; see https://github.com/biocommons/eutils/issues/124/
#   0 - The long non-coding RNA
#   1 - Circulating HOTAIR expression predicts the clinical response to neoadjuvant chemotherapy in patients with breast cancer.
#   2 - HOTAIR gene polymorphisms contribute to increased neuroblastoma susceptibility in Chinese children.
#   3 - Long non-coding RNAs in melanoma.
#   4 - Long non-coding RNA HOTAIR and STAT3 synergistically regulate the cervical cancer cell migration and invasion.
#   5 - Serum long noncoding RNA HOTAIR as a novel diagnostic and prognostic biomarker in glioblastoma multiforme.
#   6 - STAT3/HOTAIR Signaling Axis Regulates HNSCC Growth in an EZH2-dependent Manner.
#   7 - An Overview of Long Noncoding RNAs Involved in Bone Regeneration from Mesenchymal Stem Cells.
#   8 - The association between LncRNA HOTAIR and cancer lymph node metastasis and distant metastasis: a meta-analysis.
# ...
